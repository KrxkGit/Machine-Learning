# %%
import torch
from torch import nn
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from d2l import torch as d2l

# %%
def comp_conv2d(conv2d, X):
    X = X.reshape((1, 1) + X.shape)   # 这里的（1，1）表示批量大小和通道数都是1
    print(X.shape)
    Y = conv2d(X)
    print(Y)
    return Y.reshape(Y.shape[2:])  # 丢弃通道信息

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=3, padding=1) # 请注意，这里每边都填充了1行或1列，因此总共添加了2行或2列
X = torch.rand((8, 8))
print(X)
comp_conv2d(conv2d, X) 
comp_conv2d(conv2d, X).shape
# Out:
# tensor([[0.0663, 0.1587, 0.3596, 0.8480, 0.9392, 0.5195, 0.0026, 0.3770],
#         [0.4892, 0.7026, 0.1099, 0.9106, 0.7703, 0.1215, 0.1154, 0.8802],
#         [0.3601, 0.0851, 0.4304, 0.6511, 0.4028, 0.4977, 0.4726, 0.6108],
#         [0.5347, 0.2461, 0.0672, 0.2081, 0.1197, 0.0726, 0.6680, 0.3061],
#         [0.2655, 0.6500, 0.1622, 0.7950, 0.6576, 0.0014, 0.2558, 0.7013],
#         [0.4054, 0.2159, 0.5321, 0.8541, 0.6898, 0.7942, 0.1983, 0.0022],
#         [0.1815, 0.4558, 0.9548, 0.0207, 0.7847, 0.9667, 0.7213, 0.1025],
#         [0.3256, 0.7883, 0.8361, 0.3468, 0.7386, 0.7855, 0.3731, 0.7133]])
# torch.Size([1, 1, 8, 8])
# tensor([[[[-0.3099, -0.3163, -0.4908, -0.2817, -0.4746, -0.4729, -0.2442,
#            -0.3171],
#           [-0.1692, -0.4201,  0.1643, -0.2717, -0.4036, -0.2266, -0.0955,
#            -0.6307],
#           [-0.2097, -0.2824,  0.0342, -0.1943, -0.1481, -0.2166,  0.0837,
#            -0.6461],
#           [-0.4604, -0.1011, -0.3814, -0.2950, -0.2611, -0.2375, -0.2755,
#            -0.2640],
#           [-0.1927, -0.4831, -0.0726, -0.4891, -0.6002, -0.0670, -0.4104,
#            -0.4067],
#           [-0.2332, -0.3129,  0.0667, -0.5816, -0.1848, -0.4151, -0.2718,
#            -0.5177],
#           [-0.3056, -0.1232, -0.4787, -0.1290, -0.1794, -0.4048, -0.4970,
#            -0.1766],
#           [-0.0564,  0.0131, -0.3309,  0.3441, -0.0565, -0.0771,  0.0165,
#            -0.2823]]]], grad_fn=<ConvolutionBackward0>)
# torch.Size([1, 1, 8, 8])
# tensor([[[[-0.3099, -0.3163, -0.4908, -0.2817, -0.4746, -0.4729, -0.2442,
#            -0.3171],
#           [-0.1692, -0.4201,  0.1643, -0.2717, -0.4036, -0.2266, -0.0955,
#            -0.6307],
#           [-0.2097, -0.2824,  0.0342, -0.1943, -0.1481, -0.2166,  0.0837,
#            -0.6461],
#           [-0.4604, -0.1011, -0.3814, -0.2950, -0.2611, -0.2375, -0.2755,
#            -0.2640],
#           [-0.1927, -0.4831, -0.0726, -0.4891, -0.6002, -0.0670, -0.4104,
#            -0.4067],
#           [-0.2332, -0.3129,  0.0667, -0.5816, -0.1848, -0.4151, -0.2718,
#            -0.5177],
#           [-0.3056, -0.1232, -0.4787, -0.1290, -0.1794, -0.4048, -0.4970,
#            -0.1766],
#           [-0.0564,  0.0131, -0.3309,  0.3441, -0.0565, -0.0771,  0.0165,
#            -0.2823]]]], grad_fn=<ConvolutionBackward0>)
# torch.Size([8, 8])

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=(5, 3), padding=(2, 1))
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([1, 1, 8, 8])
# tensor([[[[ 0.0918,  0.1097,  0.2823,  0.1987,  0.1492,  0.0777,  0.1149,
#             0.0540],
#           [ 0.2009,  0.1029,  0.2917,  0.3038,  0.2880,  0.2326,  0.4782,
#             0.0359],
#           [-0.0466,  0.3411,  0.2673,  0.1173,  0.4938,  0.3447,  0.0426,
#             0.2144],
#           [ 0.0650,  0.1741, -0.0009,  0.1923,  0.3196,  0.4202,  0.1211,
#             0.2735],
#           [ 0.1812,  0.0669,  0.3831,  0.1281,  0.0300,  0.1980,  0.3498,
#             0.2781],
#           [ 0.0647,  0.1873,  0.4238,  0.2673,  0.3022,  0.2045,  0.1358,
#             0.2746],
#           [ 0.1051,  0.4584, -0.0051,  0.5152,  0.5450,  0.3038,  0.2529,
#             0.2093],
#           [ 0.2877,  0.2142,  0.1366,  0.5057,  0.1791,  0.3524,  0.4227,
#             0.1700]]]], grad_fn=<ConvolutionBackward0>)
# torch.Size([8, 8])
